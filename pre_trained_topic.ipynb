# %%
import pandas as pd
from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired

# %%
representation_model = KeyBERTInspired()
topic_model = BERTopic("english", verbose=True, nr_topics=10, representation_model=representation_model)

# %%
df=pd.read_csv("Womens Clothing E-Commerce Reviews.csv")

# %%
df1=df[["Review Text"]]
df1.dropna(inplace=True)
sample=df1["Review Text"].to_list()
print(sample[0])

# %%
topics, probs = topic_model.fit_transform(sample)
freq = topic_model.get_topic_info()
# Out:
# 2024-09-29 07:26:01,032 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/708 [00:00<?, ?it/s]
# 2024-09-29 07:41:48,627 - BERTopic - Embedding - Completed ✓
# 2024-09-29 07:41:48,629 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-09-29 07:42:12,811 - BERTopic - Dimensionality - Completed ✓
# 2024-09-29 07:42:12,814 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-09-29 07:42:20,748 - BERTopic - Cluster - Completed ✓
# 2024-09-29 07:42:20,749 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2024-09-29 07:43:19,446 - BERTopic - Representation - Completed ✓
# 2024-09-29 07:43:19,448 - BERTopic - Topic reduction - Reducing number of topics
# 2024-09-29 07:43:26,058 - BERTopic - Topic reduction - Reduced number of topics from 178 to 10

# %%
freq
# Out:
#    Topic  Count                                        Name  \
# 0     -1   9889                  -1_dress_fabric_wear_jeans
# 1      0  10775                  0_size_petite_medium_dress
# 2      1   1380                  1_jeans_pants_shorts_denim
# 3      2    347                  2_sweater_ivory_shirt_size
# 4      3    126               3_romper_rompers_petite_torso
# 5      4     49               4_washed_wash_washing_laundry
# 6      5     32                    5_dress_beach_suit_cover
# 7      6     17                6_shorty_length_short_taller
# 8      7     14             7_medium_34a_large_measurements
# 9      8     12  8_leather_jacket_leatherthick_leathervegan
#
#                                       Representation  \
# 0  [dress, fabric, wear, jeans, comfortable, medi...
# 1  [size, petite, medium, dress, small, fit, swea...
# 2  [jeans, pants, shorts, denim, waist, leggings,...
# 3  [sweater, ivory, shirt, size, fabric, black, w...
# 4  [romper, rompers, petite, torso, small, size, ...
# 5  [washed, wash, washing, laundry, wear, dry, pa...
# 6  [dress, beach, suit, cover, wear, coverup, bat...
# 7  [shorty, length, short, taller, long, longthe,...
# 8  [medium, 34a, large, measurements, wearing, sm...
# 9  [leather, jacket, leatherthick, leathervegan, ...
#
#                                  Representative_Docs
# 0  [The dress is absolutely beautiful. the fabric...
# 1  [I bought this in the mauve in my usual size s...
# 2  [First off, the pictures online hardly do thes...
# 3  [I bought this in both the black motif and the...
# 4  [I tried on this romper when it was still full...
# 5  [I love the relaxed flattering fit of these pa...
# 6  [I got this to wear as a beach cover-up over b...
# 7  [I&#39;m taller (5&#39;8), so it&#39;s not unc...
# 8  [For reference i am wearing a medium in the ph...
# 9  [I really like the soft and very wearability o...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="23bbff2c-231c-4c5a-8b06-f11cfab3f8c3" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23bbff2c-231c-4c5a-8b06-f11cfab3f8c3")) {                    Plotly.newPlot(                        "23bbff2c-231c-4c5a-8b06-f11cfab3f8c3",                        [{"customdata":[[0,"size | petite | medium | dress | small",10775],[1,"jeans | pants | shorts | denim | waist",1380],[2,"sweater | ivory | shirt | size | fabric",347],[3,"romper | rompers | petite | torso | small",126],[4,"washed | wash | washing | laundry | wear",49],[5,"dress | beach | suit | cover | wear",32],[6,"shorty | length | short | taller | long",17],[7,"medium | 34a | large | measurements | wearing",14],[8,"leather | jacket | leatherthick | leathervegan | jackets",12]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[10775,1380,347,126,49,32,17,14,12],"sizemode":"area","sizeref":6.734375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[9.3038969039917,10.928265571594238,9.377692222595215,9.973860740661621,11.381430625915527,9.15550422668457,8.670243263244629,9.00363540649414,9.771535873413086],"xaxis":"x","y":[1.9786367416381836,1.5376396179199219,2.560379981994629,2.265392303466797,1.4265549182891846,0.7180174589157104,2.162386417388916,1.5210117101669312,1.5470978021621704],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinew ...
